# %%
# %load_ext autoreload
# %autoreload 2
from typing import List


import torch
from PIL import Image


from mmline import MyPipeline
from utils import ptp_utils
from utils.ptp_utils import AttentionStore

import warnings
import os
warnings.filterwarnings("ignore", category=UserWarning)


device = torch.device('cuda:1') if torch.cuda.is_available() else torch.device('cpu')
stable_diffusion_version = "/home/khf/liutao/sd1-4"
model = MyPipeline.from_pretrained(stable_diffusion_version).to(device)

controller = AttentionStore()



# prompt = " A lemon next to an apple"
# prompt = "A lemon next to a green apple"
# prompt = "a man in red standing next to another woman in blue"
# prompt = "A cat and a frog"
# prompt = "A cat and a frog are playing with a dog"
# prompt = "A yellow bowl and a turtle"
# prompt = "A bird and a red chair"
# prompt = "A white horse and a green bird"
# prompt = "A watermelon and an apple"
prompt = "A bear and a turtle"
# prompt = "a dog is on the beach with an umbrella"
# prompt = "A horse and a dog"

attention_res = 16
guidance_scale = 7.5
iterative_refinement = False
seed = 8888
g = torch.Generator().manual_seed(seed)
n_inference_steps = 50
indices_to_compute = [(1, 4)]
scale_factor = 25
show_attention_per_step = True
run_standard_sd = False
max_iter_to_alter = 35
scale_range = (1., 0.5)
run_structure_sd = False



ptp_utils.register_attention_control(model, controller)
outputs = model(prompt = prompt,
                attention_store=controller,
                attention_res=attention_res,
                guidance_scale = guidance_scale,
                generator=g,
                num_inference_steps=n_inference_steps,
                scale_factor = scale_factor,
                scale_range = scale_range,
                max_iter_to_alter = max_iter_to_alter,
                show_attention_per_step = show_attention_per_step,
                run_standard_sd = run_standard_sd,
                run_structure_sd = run_structure_sd,
                iterative_refinement = iterative_refinement,
                indices_to_compute = indices_to_compute
                )

image = outputs.images[0]
display(image)
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=L size=1280x307>
# compute loss between bear and turtle.
# Iteration 0 | Loss: 0.9390
# <PIL.Image.Image image mode=L size=1280x307>
#   2%|▏         | 1/50 [00:00<00:26,  1.82it/s]
# compute loss between bear and turtle.
# Iteration 1 | Loss: 0.8599
# <PIL.Image.Image image mode=L size=1280x307>
#   4%|▍         | 2/50 [00:00<00:17,  2.70it/s]
# compute loss between bear and turtle.
# Iteration 2 | Loss: 0.8586
# <PIL.Image.Image image mode=L size=1280x307>
#   6%|▌         | 3/50 [00:01<00:14,  3.19it/s]
# compute loss between bear and turtle.
# Iteration 3 | Loss: 0.7455
# <PIL.Image.Image image mode=L size=1280x307>
#   8%|▊         | 4/50 [00:01<00:13,  3.49it/s]
# compute loss between bear and turtle.
# Iteration 4 | Loss: 0.6610
# <PIL.Image.Image image mode=L size=1280x307>
#  10%|█         | 5/50 [00:01<00:12,  3.67it/s]
# compute loss between bear and turtle.
# Iteration 5 | Loss: 0.5251
# <PIL.Image.Image image mode=L size=1280x307>
#  12%|█▏        | 6/50 [00:01<00:11,  3.79it/s]
# compute loss between bear and turtle.
# Iteration 6 | Loss: 0.5034
# <PIL.Image.Image image mode=L size=1280x307>
#  14%|█▍        | 7/50 [00:02<00:11,  3.86it/s]
# compute loss between bear and turtle.
# Iteration 7 | Loss: 0.5934
# <PIL.Image.Image image mode=L size=1280x307>
#  16%|█▌        | 8/50 [00:02<00:10,  3.92it/s]
# compute loss between bear and turtle.
# Iteration 8 | Loss: 0.4171
# <PIL.Image.Image image mode=L size=1280x307>
#  18%|█▊        | 9/50 [00:02<00:10,  3.97it/s]
# compute loss between bear and turtle.
# Iteration 9 | Loss: 0.4527
# <PIL.Image.Image image mode=L size=1280x307>
#  20%|██        | 10/50 [00:02<00:10,  4.00it/s]
# compute loss between bear and turtle.
# Iteration 10 | Loss: 0.4043
# <PIL.Image.Image image mode=L size=1280x307>
#  22%|██▏       | 11/50 [00:03<00:09,  4.01it/s]
# compute loss between bear and turtle.
# Iteration 11 | Loss: 0.3560
# <PIL.Image.Image image mode=L size=1280x307>
#  24%|██▍       | 12/50 [00:03<00:09,  4.05it/s]
# compute loss between bear and turtle.
# Iteration 12 | Loss: 0.3199
# <PIL.Image.Image image mode=L size=1280x307>
#  26%|██▌       | 13/50 [00:03<00:09,  4.04it/s]
# compute loss between bear and turtle.
# Iteration 13 | Loss: 0.2956
# <PIL.Image.Image image mode=L size=1280x307>
#  28%|██▊       | 14/50 [00:03<00:08,  4.04it/s]
# compute loss between bear and turtle.
# Iteration 14 | Loss: 0.2690
# <PIL.Image.Image image mode=L size=1280x307>
#  30%|███       | 15/50 [00:03<00:08,  4.05it/s]
# compute loss between bear and turtle.
# Iteration 15 | Loss: 0.2627
# <PIL.Image.Image image mode=L size=1280x307>
#  32%|███▏      | 16/50 [00:04<00:08,  4.07it/s]
# compute loss between bear and turtle.
# Iteration 16 | Loss: 0.2103
# <PIL.Image.Image image mode=L size=1280x307>
#  34%|███▍      | 17/50 [00:04<00:08,  4.08it/s]
# compute loss between bear and turtle.
# Iteration 17 | Loss: 0.2685
# <PIL.Image.Image image mode=L size=1280x307>
#  36%|███▌      | 18/50 [00:04<00:07,  4.09it/s]
# compute loss between bear and turtle.
# Iteration 18 | Loss: 0.2095
# <PIL.Image.Image image mode=L size=1280x307>
#  38%|███▊      | 19/50 [00:04<00:07,  4.08it/s]
# compute loss between bear and turtle.
# Iteration 19 | Loss: 0.2245
# <PIL.Image.Image image mode=L size=1280x307>
#  40%|████      | 20/50 [00:05<00:07,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 20 | Loss: 0.1945
# <PIL.Image.Image image mode=L size=1280x307>
#  42%|████▏     | 21/50 [00:05<00:07,  4.08it/s]
# compute loss between bear and turtle.
# Iteration 21 | Loss: 0.2126
# <PIL.Image.Image image mode=L size=1280x307>
#  44%|████▍     | 22/50 [00:05<00:06,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 22 | Loss: 0.1947
# <PIL.Image.Image image mode=L size=1280x307>
#  46%|████▌     | 23/50 [00:05<00:06,  4.07it/s]
# compute loss between bear and turtle.
# Iteration 23 | Loss: 0.1929
# <PIL.Image.Image image mode=L size=1280x307>
#  48%|████▊     | 24/50 [00:06<00:06,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 24 | Loss: 0.2161
# <PIL.Image.Image image mode=L size=1280x307>
#  50%|█████     | 25/50 [00:06<00:06,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 25 | Loss: 0.1950
# <PIL.Image.Image image mode=L size=1280x307>
#  52%|█████▏    | 26/50 [00:06<00:05,  4.04it/s]
# compute loss between bear and turtle.
# Iteration 26 | Loss: 0.1872
# <PIL.Image.Image image mode=L size=1280x307>
#  54%|█████▍    | 27/50 [00:06<00:05,  4.05it/s]
# compute loss between bear and turtle.
# Iteration 27 | Loss: 0.1373
# <PIL.Image.Image image mode=L size=1280x307>
#  56%|█████▌    | 28/50 [00:07<00:05,  4.04it/s]
# compute loss between bear and turtle.
# Iteration 28 | Loss: 0.1380
# <PIL.Image.Image image mode=L size=1280x307>
#  58%|█████▊    | 29/50 [00:07<00:05,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 29 | Loss: 0.1234
# <PIL.Image.Image image mode=L size=1280x307>
#  60%|██████    | 30/50 [00:07<00:04,  4.05it/s]
# compute loss between bear and turtle.
# Iteration 30 | Loss: 0.1164
# <PIL.Image.Image image mode=L size=1280x307>
#  62%|██████▏   | 31/50 [00:07<00:04,  4.06it/s]
# compute loss between bear and turtle.
# Iteration 31 | Loss: 0.1228
# <PIL.Image.Image image mode=L size=1280x307>
#  64%|██████▍   | 32/50 [00:08<00:04,  4.04it/s]
# compute loss between bear and turtle.
# Iteration 32 | Loss: 0.1070
# <PIL.Image.Image image mode=L size=1280x307>
#  66%|██████▌   | 33/50 [00:08<00:04,  4.03it/s]
# compute loss between bear and turtle.
# Iteration 33 | Loss: 0.1013
# <PIL.Image.Image image mode=L size=1280x307>
#  68%|██████▊   | 34/50 [00:08<00:03,  4.03it/s]
# compute loss between bear and turtle.
# Iteration 34 | Loss: 0.1046
# <PIL.Image.Image image mode=L size=1280x307>
#  70%|███████   | 35/50 [00:08<00:03,  4.38it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  72%|███████▏  | 36/50 [00:09<00:03,  4.64it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  74%|███████▍  | 37/50 [00:09<00:02,  4.84it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  76%|███████▌  | 38/50 [00:09<00:02,  4.99it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  78%|███████▊  | 39/50 [00:09<00:02,  5.10it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  80%|████████  | 40/50 [00:09<00:01,  5.18it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  82%|████████▏ | 41/50 [00:09<00:01,  5.25it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  84%|████████▍ | 42/50 [00:10<00:01,  5.28it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  86%|████████▌ | 43/50 [00:10<00:01,  5.31it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  88%|████████▊ | 44/50 [00:10<00:01,  5.33it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  90%|█████████ | 45/50 [00:10<00:00,  5.35it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  92%|█████████▏| 46/50 [00:10<00:00,  5.35it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  94%|█████████▍| 47/50 [00:11<00:00,  5.36it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  96%|█████████▌| 48/50 [00:11<00:00,  5.36it/s]
# <PIL.Image.Image image mode=L size=1280x307>
#  98%|█████████▊| 49/50 [00:11<00:00,  5.37it/s]
# <PIL.Image.Image image mode=L size=1280x307>
# 100%|██████████| 50/50 [00:11<00:00,  4.29it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### 测试案例

# %%
import numpy as np

h, w, c = images[0].shape  # get image size

# 获取行、列
num_rows = 1
num_cols = len(images) // num_rows

# 定义画布
image_ = np.ones((h * num_rows, w * num_cols, 3))

for i in range(num_rows):
    for j in range(num_cols):
        idx = i * num_cols + j  #图片序号
        image_[i * h : i * h + h , j * w : j * w + w ] = images[idx]

image_ = model.numpy_to_pil(image_)[0]
display(image_)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x512>
